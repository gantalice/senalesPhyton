# %% [markdown]
# <a href="https://colab.research.google.com/github/gantalice/senalesPhyton/blob/master/Clase2semana2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# My first code here

# %%
import numpy as np
import matplotlib.pyplot as plt

#Ingreso

a = -5 # rango de tiempo
b = 5
dt= 0.1
sigma = 0 # s= 0+0j
omega = 0

#Procedimiento
t = np.arange(a, b, dt)
s = complex(sigma, omega)
senal = np.exp(s*t)

#Salida - grafica
plt.figure(1)
plt.plot(t, np.real(senal), label = 'Real')
plt.plot(t, np.imag(senal), label = 'Imaginaria')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.legend()
plt.margins(0.1)
plt.title('e^('+str(sigma) + '+' + str(omega) + 'j)')
plt.show()

# %%
sigma = 1 # s= 0+0j
omega = 0

#Procedimiento
t = np.arange(a, b, dt)
s = complex(sigma, omega)
senal = np.exp(s*t)

#Salida - grafica
plt.figure(1)
plt.plot(t, np.real(senal), label = 'Real')
plt.plot(t, np.imag(senal), label = 'Imaginaria')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.legend()
plt.margins(0.1)
plt.title('e^('+str(sigma) + '+' + str(omega) + 'j)')
plt.show()

# %%
sigma = 0 # s= 0+0j
omega = 1

#Procedimiento
t = np.arange(a, b, dt)
s = complex(sigma, omega)
senal = np.exp(s*t)

#Salida - grafica
plt.figure(1)
plt.plot(t, np.real(senal), label = 'Real')
plt.plot(t, np.imag(senal), label = 'Imaginaria')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.legend()
plt.margins(0.1)
plt.title('e^('+str(sigma) + '+' + str(omega) + 'j)')
plt.show()

# %%
sigma = 0 # s= 0+0j
omega = 1

#Procedimiento
#t = np.arange(a, b, dt)
s = complex(sigma, omega)
senal = np.exp(s*t)

#Salida - grafica
plt.figure(1)
plt.plot(np.real(senal), np.imag(senal), label = 'Complejo')
#No va -> plt.plot(t, np.imag(senal), label = 'Imaginaria')
plt.xlabel('Real')
plt.ylabel('Imaginario')
plt.legend()
plt.margins(0.1)
plt.title('e^('+str(sigma) + '+' + str(omega) + 'j)')
plt.show()

# %%
import scipy.integrate as integrate

#Ingreso Parametros
w=1
a =0.8
b=0
c= 2*np.pi #un periodo
dte = 0.005

#Procedimiento
te = np.arange(b, c, dte)
xe = np.exp(-a*te)

cuadradoxe = xe**2
energiaxe = integrate.simps(cuadradoxe, te)

#Salida
print('la energia de xe es: ', energiaxe)

#Grafica
plt.plot(te, xe, label = 'xe')
plt.fill_between(te, 0, cuadradoxe, color = 'lightgreen')
plt.plot(te, cuadradoxe, 'g--', label = 'xe ^2')
plt.xlabel('t')
plt.legend()
plt.show()
# Out:
# la energia de xe es:  0.6249729548848542

# %%
#Ingreso
w = 1
a = 0
b = 2*np.pi #Un periodo
dte = 0.005
Q = 0
A = 2

#Procedimiento
T = 2*np.pi/w
te = np.arange(a, b, dte)
xe = A*np.cos(w*te+Q)

#Energia de un periodo
cuadradoxe = xe**2
energiaxe = integrate.simps(cuadradoxe, te)

#Potencia en un periodo
potenciaxe = (1/T)*energiaxe

#Salida
print('la potencia de xe es: ', potenciaxe)
#Grafica
plt.plot(te, xe, label = 'xe')
plt.fill_between(te, 0, cuadradoxe, color = 'lightgreen')
plt.plot(te, cuadradoxe, 'g--', label = 'xe^2')
plt.xlabel('t')
plt.legend()
plt.show()
# Out:
# la potencia de xe es:  1.9979721773265833
